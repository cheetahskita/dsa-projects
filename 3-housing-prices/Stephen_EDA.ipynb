# %%
# import necessary packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %%
# import dataset
housing = pd.read_csv('Ames_HousePrice.csv', index_col=0)
real_estate = pd.read_csv('./data/Ames_Real_Estate_Data.csv')
# Out:
# D:\Software\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (36,40,81,87) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # Basic EDA

# %%
housing.head()
# Out:
#          PID  GrLivArea  SalePrice  MSSubClass MSZoning  LotFrontage  LotArea  \
# 1  909176150        856     126000          30       RL          NaN     7890
# 2  905476230       1049     139500         120       RL         42.0     4235
# 3  911128020       1001     124900          30  C (all)         60.0     6060
# 4  535377150       1039     114000          70       RL         80.0     8146
# 5  534177230       1665     227000          60       RL         70.0     8400
#
#   Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 1   Pave   NaN      Reg         Lvl    AllPub    Corner       Gtl
# 2   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 3   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 4   Pave   NaN      Reg         Lvl    AllPub    Corner       Gtl
# 5   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
#
#   Neighborhood Condition1 Condition2 BldgType HouseStyle  OverallQual  \
# 1        SWISU       Norm       Norm     1Fam     1Story            6
# 2      Edwards       Norm       Norm   TwnhsE     1Story            5
# 3       IDOTRR       Norm       Norm     1Fam     1Story            5
# 4      OldTown       Norm       Norm     1Fam     2Story            4
# 5       NWAmes       Norm       Norm     1Fam     2Story            8
#
#    OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st  \
# 1            6       1939          1950     Gable  CompShg     Wd Sdng
# 2            5       1984          1984     Gable  CompShg     HdBoard
# 3            9       1930          2007       Hip  CompShg     MetalSd
# 4            8       1900          2003     Gable  CompShg     MetalSd
# 5            6       2001          2001     Gable  CompShg     VinylSd
#
#   Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond Foundation BsmtQual  \
# 1     Wd Sdng       None         0.0        TA        TA     CBlock       TA
# 2     HdBoard    BrkFace       149.0        Gd        TA     CBlock       Gd
# 3     MetalSd       None         0.0        Gd        TA     BrkTil       TA
# 4     MetalSd       None         0.0        Gd        Gd     BrkTil       Fa
# 5     VinylSd       None         0.0        Gd        TA      PConc       Gd
#
#   BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 1       TA           No          Rec       238.0          Unf         0.0
# 2       TA           Mn          GLQ       552.0          ALQ       393.0
# 3       TA           No          ALQ       737.0          Unf         0.0
# 4       TA           No          Unf         0.0          Unf         0.0
# 5       TA           No          GLQ       643.0          Unf         0.0
#
#    BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  1stFlrSF  \
# 1      618.0        856.0    GasA        TA          Y      SBrkr       856
# 2      104.0       1049.0    GasA        TA          Y      SBrkr      1049
# 3      100.0        837.0    GasA        Ex          Y      SBrkr      1001
# 4      405.0        405.0    GasA        Gd          Y      SBrkr       717
# 5      167.0        810.0    GasA        Ex          Y      SBrkr       810
#
#    2ndFlrSF  LowQualFinSF  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  \
# 1         0             0           1.0           0.0         1         0
# 2         0             0           1.0           0.0         2         0
# 3         0             0           0.0           0.0         1         0
# 4       322             0           0.0           0.0         1         0
# 5       855             0           1.0           0.0         2         1
#
#    BedroomAbvGr  KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  \
# 1             2             1          TA             4        Typ
# 2             2             1          Gd             5        Typ
# 3             2             1          Gd             5        Typ
# 4             2             1          TA             6        Typ
# 5             3             1          Gd             6        Typ
#
#    Fireplaces FireplaceQu GarageType  GarageYrBlt GarageFinish  GarageCars  \
# 1           1          Gd     Detchd       1939.0          Unf         2.0
# 2           0         NaN     Attchd       1984.0          Fin         1.0
# 3           0         NaN     Detchd       1930.0          Unf         1.0
# 4           0         NaN     Detchd       1940.0          Unf         1.0
# 5           0         NaN     Attchd       2001.0          Fin         2.0
#
#    GarageArea GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  \
# 1       399.0         TA         TA          Y           0            0
# 2       266.0         TA         TA          Y           0          105
# 3       216.0         TA         Po          N         154            0
# 4       281.0         TA         TA          N           0            0
# 5       528.0         TA         TA          Y           0           45
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea PoolQC Fence MiscFeature  \
# 1              0          0          166         0    NaN   NaN         NaN
# 2              0          0            0         0    NaN   NaN         NaN
# 3             42         86            0         0    NaN   NaN         NaN
# 4            168          0          111         0    NaN   NaN         NaN
# 5              0          0            0         0    NaN   NaN         NaN
#
#    MiscVal  MoSold  YrSold SaleType SaleCondition
# 1        0       3    2010      WD         Normal
# 2        0       2    2009      WD         Normal
# 3        0      11    2007      WD         Normal
# 4        0       5    2009      WD         Normal
# 5        0      11    2009      WD         Normal

# %%
housing.sort_values('SalePrice', ascending=False).head(5)
# Out:
#            PID  GrLivArea  SalePrice  MSSubClass MSZoning  LotFrontage  \
# 8    528351010       4316     755000          60       RL        104.0
# 326  528320060       3627     625000          60       RL        118.0
# 66   528164060       2470     615000          20       RL        106.0
# 585  528150070       2364     611657          20       RL        100.0
# 640  528110020       2674     610000          20       RL        105.0
#
#      LotArea Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 8      21535   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 326    35760   Pave   NaN      IR1         Lvl    AllPub   CulDSac       Gtl
# 66     12720   Pave   NaN      Reg         HLS    AllPub    Inside       Mod
# 585    12919   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 640    13693   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
#
#     Neighborhood Condition1 Condition2 BldgType HouseStyle  OverallQual  \
# 8        NoRidge       Norm       Norm     1Fam     2Story           10
# 326      NoRidge       Norm       Norm     1Fam     2Story           10
# 66       NridgHt       Norm       Norm     1Fam     1Story           10
# 585      NridgHt       Norm       Norm     1Fam     1Story            9
# 640      NridgHt       PosA       PosA     1Fam     1Story           10
#
#      OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st  \
# 8              6       1994          1995     Gable  WdShngl     HdBoard
# 326            5       1995          1996       Hip  CompShg     HdBoard
# 66             5       2003          2003       Hip  CompShg     MetalSd
# 585            5       2009          2010       Hip  CompShg     VinylSd
# 640            5       2007          2007       Hip  CompShg     VinylSd
#
#     Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond Foundation  \
# 8       HdBoard    BrkFace      1170.0        Ex        TA      PConc
# 326     HdBoard    BrkFace      1378.0        Gd        Gd      PConc
# 66      MetalSd      Stone       680.0        Ex        TA      PConc
# 585     VinylSd      Stone       760.0        Ex        TA      PConc
# 640     VinylSd      Stone       472.0        Ex        TA      PConc
#
#     BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  \
# 8         Ex       TA           Gd          GLQ      1455.0          Unf
# 326       Ex       TA           Gd          GLQ      1387.0          Unf
# 66        Ex       TA           Gd          GLQ      2257.0          Unf
# 585       Ex       TA           Gd          GLQ      2188.0          Unf
# 640       Ex       TA           Gd          GLQ      2288.0          Unf
#
#      BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir  \
# 8           0.0      989.0       2444.0    GasA        Ex          Y
# 326         0.0      543.0       1930.0    GasA        Ex          Y
# 66          0.0      278.0       2535.0    GasA        Ex          Y
# 585         0.0      142.0       2330.0    GasA        Ex          Y
# 640         0.0      342.0       2630.0    GasA        Ex          Y
#
#     Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  BsmtFullBath  BsmtHalfBath  \
# 8        SBrkr      2444      1872             0           0.0           1.0
# 326      SBrkr      1831      1796             0           1.0           0.0
# 66       SBrkr      2470         0             0           2.0           0.0
# 585      SBrkr      2364         0             0           1.0           0.0
# 640      SBrkr      2674         0             0           2.0           0.0
#
#      FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  TotRmsAbvGrd  \
# 8           3         1             4             1          Ex            10
# 326         3         1             4             1          Gd            10
# 66          1         1             1             1          Ex             7
# 585         2         1             2             1          Ex            11
# 640         2         1             2             1          Ex             8
#
#     Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt GarageFinish  \
# 8          Typ           2          Ex     Attchd       1994.0          Fin
# 326        Typ           1          TA     Attchd       1995.0          Fin
# 66         Typ           2          Gd     Attchd       2003.0          Fin
# 585        Typ           2          Gd     Attchd       2009.0          Fin
# 640        Typ           2          Gd     Attchd       2007.0          Fin
#
#      GarageCars  GarageArea GarageQual GarageCond PavedDrive  WoodDeckSF  \
# 8           3.0       832.0         TA         TA          Y         382
# 326         3.0       807.0         TA         TA          Y         361
# 66          3.0       789.0         TA         TA          Y         154
# 585         3.0       820.0         TA         TA          Y           0
# 640         3.0       762.0         TA         TA          Y         360
#
#      OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea PoolQC  \
# 8             50              0          0            0         0    NaN
# 326           76              0          0            0         0    NaN
# 66            65              0          0          216       144     Ex
# 585           67              0          0            0         0    NaN
# 640           50              0          0            0         0    NaN
#
#     Fence MiscFeature  MiscVal  MoSold  YrSold SaleType SaleCondition
# 8     NaN         NaN        0       1    2007      WD         Normal
# 326   NaN         NaN        0       7    2006      WD         Normal
# 66    NaN         NaN        0       2    2008      WD         Normal
# 585   NaN         NaN        0       3    2010      New       Partial
# 640   NaN         NaN        0       3    2009      WD         Normal

# %%
plt.figure(figsize=(6,6))
housing['SalePrice'].hist()
plt.title('Price Distribution')
# Out:
# Text(0.5, 1.0, 'Price Distribution')

# %%
print('SalePrice Mean: ', np.mean(housing.SalePrice))

upper_lim = np.mean(housing.SalePrice) + 3 * np.std(housing.SalePrice)
lower_lim = np.mean(housing.SalePrice) - 3 * np.std(housing.SalePrice)
print('Outliers are above %.2f and below %.2f' % (upper_lim, lower_lim))
# Out:
# SalePrice Mean:  178059.62325581396
# Outliers are above 403109.26 and below -46990.02

# %%
housing['LogSalePrice'] = np.log(housing.SalePrice)
housing['LogGrLivArea'] = np.log(housing.GrLivArea)
housing['LogLotArea'] = np.log(housing.LotArea)
plt.figure(figsize=(6,6))
housing['LogSalePrice'].hist()
plt.title('Log Price Distribution')
# Out:
# Text(0.5, 1.0, 'Log Price Distribution')

# %%
print('Log SalePrice Mean: %.1f' % np.mean(housing.LogSalePrice))

upper_lim = np.mean(housing.LogSalePrice) + 3.5 * np.std(housing.LogSalePrice)
lower_lim = np.mean(housing.LogSalePrice) - 3.5 * np.std(housing.LogSalePrice)
print('Outliers are above %.1f and below %.1f' % (upper_lim, lower_lim))
# Out:
# Log SalePrice Mean: 12.0
# Outliers are above 13.4 and below 10.7

# %%
housing[housing.LogSalePrice > 13.4].sort_values('LogSalePrice', ascending=False)
# Out:
#          PID  GrLivArea  SalePrice  MSSubClass MSZoning  LotFrontage  LotArea  \
# 8  528351010       4316     755000          60       RL        104.0    21535
#
#   Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 8   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
#
#   Neighborhood Condition1 Condition2 BldgType HouseStyle  OverallQual  \
# 8      NoRidge       Norm       Norm     1Fam     2Story           10
#
#    OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st  \
# 8            6       1994          1995     Gable  WdShngl     HdBoard
#
#   Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond Foundation BsmtQual  \
# 8     HdBoard    BrkFace      1170.0        Ex        TA      PConc       Ex
#
#   BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 8       TA           Gd          GLQ      1455.0          Unf         0.0
#
#    BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  1stFlrSF  \
# 8      989.0       2444.0    GasA        Ex          Y      SBrkr      2444
#
#    2ndFlrSF  LowQualFinSF  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  \
# 8      1872             0           0.0           1.0         3         1
#
#    BedroomAbvGr  KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  \
# 8             4             1          Ex            10        Typ
#
#    Fireplaces FireplaceQu GarageType  GarageYrBlt GarageFinish  GarageCars  \
# 8           2          Ex     Attchd       1994.0          Fin         3.0
#
#    GarageArea GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  \
# 8       832.0         TA         TA          Y         382           50
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea PoolQC Fence MiscFeature  \
# 8              0          0            0         0    NaN   NaN         NaN
#
#    MiscVal  MoSold  YrSold SaleType SaleCondition  LogSalePrice  LogGrLivArea  \
# 8        0       1    2007      WD         Normal     13.534473      8.370084
#
#    LogLotArea
# 8    9.977435

# %%
housing[housing.LogSalePrice < 10.7].sort_values('LogSalePrice', ascending=False)
# Out:
#            PID  GrLivArea  SalePrice  MSSubClass MSZoning  LotFrontage  \
# 741  911102170       1317      40000          70  C (all)         50.0
# 918  534450090        334      39300          20       RL         50.0
# 645  911175430        480      35311          20  C (all)         50.0
# 336  909101330        498      35000          30       RL         60.0
# 559  902477120        720      34900          30  C (all)         60.0
# 428  902207130        832      12789          30       RM         68.0
#
#      LotArea Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 741     8500   Pave  Pave      Reg         Lvl    AllPub    Inside       Gtl
# 918     5000   Pave   NaN      Reg         Low    AllPub    Inside       Mod
# 645     9000   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 336     8088   Pave  Grvl      Reg         Lvl    AllPub    Inside       Gtl
# 559     7879   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 428     9656   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
#
#     Neighborhood Condition1 Condition2 BldgType HouseStyle  OverallQual  \
# 741       IDOTRR      Feedr       Norm     1Fam     2Story            4
# 918      BrkSide       Norm       Norm     1Fam     1Story            1
# 645       IDOTRR       Norm       Norm     1Fam     1Story            2
# 336      Edwards      Feedr       Norm     1Fam     1Story            2
# 559       IDOTRR       Norm       Norm     1Fam     1Story            4
# 428      OldTown       Norm       Norm     1Fam     1Story            2
#
#      OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st  \
# 741            4       1920          1950   Gambrel  CompShg     BrkFace
# 918            3       1946          1950     Gable  CompShg     VinylSd
# 645            3       1949          1950     Gable  CompShg     AsbShng
# 336            3       1922          1955     Gable  CompShg     MetalSd
# 559            5       1920          1950     Gable  CompShg     Wd Sdng
# 428            2       1923          1970     Gable  CompShg     AsbShng
#
#     Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond Foundation  \
# 741     BrkFace       None         0.0        TA        Fa     BrkTil
# 918     VinylSd       None         0.0        Fa        Fa       Slab
# 645     AsbShng       None         0.0        TA        TA     CBlock
# 336     MetalSd       None         0.0        TA        TA     BrkTil
# 559     Wd Sdng       None         0.0        TA        TA     CBlock
# 428     AsbShng       None         0.0        TA        Fa     BrkTil
#
#     BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  \
# 741       TA       TA           No          Unf         0.0          Unf
# 918      NaN      NaN          NaN          NaN         0.0          NaN
# 645       TA       TA           Av          BLQ        50.0          Unf
# 336       TA       TA           No          Unf         0.0          Unf
# 559       TA       TA           No          Rec       495.0          Unf
# 428       Fa       Fa           No          Unf         0.0          Unf
#
#      BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir  \
# 741         0.0      649.0        649.0    GasA        TA          N
# 918         0.0        0.0          0.0    GasA        Fa          N
# 645         0.0      430.0        480.0    GasA        TA          N
# 336         0.0      498.0        498.0    GasA        TA          N
# 559         0.0      225.0        720.0    GasA        TA          N
# 428         0.0      678.0        678.0    GasA        TA          N
#
#     Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  BsmtFullBath  BsmtHalfBath  \
# 741      SBrkr       649       668             0           0.0           0.0
# 918      FuseF       334         0             0           0.0           0.0
# 645      FuseA       480         0             0           1.0           0.0
# 336      FuseF       498         0             0           0.0           0.0
# 559      FuseA       720         0             0           0.0           0.0
# 428      SBrkr       832         0             0           0.0           0.0
#
#      FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  TotRmsAbvGrd  \
# 741         1         0             3             1          TA             6
# 918         1         0             1             1          Fa             2
# 645         0         0             1             1          TA             4
# 336         1         0             1             1          TA             3
# 559         1         0             2             1          TA             4
# 428         1         0             2             1          TA             5
#
#     Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt GarageFinish  \
# 741        Typ           0         NaN     Detchd       1920.0          Unf
# 918        Typ           0         NaN        NaN          NaN          NaN
# 645        Typ           0         NaN     Detchd       1958.0          Unf
# 336        Typ           0         NaN     Detchd       1922.0          Unf
# 559        Typ           0         NaN        NaN          NaN          NaN
# 428        Typ           1          Gd     Detchd       1928.0          Unf
#
#      GarageCars  GarageArea GarageQual GarageCond PavedDrive  WoodDeckSF  \
# 741         1.0       250.0         TA         Fa          N           0
# 918         0.0         0.0        NaN        NaN          N           0
# 645         1.0       308.0         TA         TA          Y           0
# 336         1.0       216.0         Fa         Fa          N           0
# 559         0.0         0.0        NaN        NaN          N           0
# 428         2.0       780.0         Fa         Fa          N           0
#
#      OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea PoolQC  \
# 741           54            172          0            0         0    NaN
# 918            0              0          0            0         0    NaN
# 645            0              0          0            0         0    NaN
# 336            0            100          0            0         0    NaN
# 559          523            115          0            0         0    NaN
# 428            0              0          0            0         0    NaN
#
#      Fence MiscFeature  MiscVal  MoSold  YrSold SaleType SaleCondition  \
# 741  MnPrv         NaN        0       7    2008      WD         Normal
# 918    NaN         NaN        0       1    2007      WD         Normal
# 645    NaN         NaN        0      10    2006      WD        Abnorml
# 336    NaN         NaN        0       2    2006    ConLD        Normal
# 559   GdWo         NaN        0      11    2009      WD        Abnorml
# 428    NaN         NaN        0       6    2010      WD        Abnorml
#
#      LogSalePrice  LogGrLivArea  LogLotArea
# 741     10.596635      7.183112    9.047821
# 918     10.578980      5.811141    8.517193
# 645     10.471950      6.173786    9.104980
# 336     10.463103      6.210600    8.998137
# 559     10.460242      6.579251    8.971956
# 428      9.456341      6.723832    9.175335

# %%
housing = housing[np.logical_and(housing.LogSalePrice > 10.7, housing.LogSalePrice < 13.4)]

# %%
# merge neighborhoods from two data sets and compare
real_estate.rename(columns = {'MapRefNo':'PID'}, inplace = True) 
real_estate = real_estate[['PID', 'Neighborhood']]
housing = housing.merge(real_estate, how='left', on='PID', suffixes=('_h','_r'))
housing.drop_duplicates(subset = ['PID'], inplace=True)

# %%
plt.figure(figsize=(6,6))
housing['Neighborhood_h'].value_counts().plot(kind='barh')
plt.title('Nieghborhood Distribution before merge')
# Out:
# Text(0.5, 1.0, 'Nieghborhood Distribution before merge')

# %%
plt.figure(figsize=(6,6))
housing['Neighborhood_r'].value_counts().plot(kind='barh')
plt.title('Nieghborhood Distribution after merge')
# Out:
# Text(0.5, 1.0, 'Nieghborhood Distribution after merge')

# %%
housing[housing.Neighborhood_h != housing.Neighborhood_r].shape
# Out:
# (888, 85)

# %%
housing[housing.Neighborhood_h != housing.Neighborhood_r][['Neighborhood_h', 'Neighborhood_r']]
# Out:
#      Neighborhood_h Neighborhood_r
# 0             SWISU        S&W ISU
# 3            IDOTRR        IDOT&RR
# 5            NWAmes        NW Ames
# 11          NridgHt        NRidgHt
# 14            NAmes         N Ames
# ...             ...            ...
# 2600          NAmes         N Ames
# 2601          NAmes         N Ames
# 2604         IDOTRR        IDOT&RR
# 2605          NAmes         N Ames
# 2610          NAmes         N Ames
#
# [888 rows x 2 columns]

# %%
housing.Neighborhood_h.value_counts()
# Out:
# NAmes      410
# CollgCr    236
# OldTown    212
# Edwards    164
# Gilbert    143
# Somerst    143
# Sawyer     139
# NWAmes     123
# NridgHt    121
# SawyerW    113
# Mitchel    104
# BrkSide    102
# Crawfor     92
# IDOTRR      73
# NoRidge     66
# Timber      54
# StoneBr     43
# SWISU       42
# ClearCr     40
# MeadowV     34
# BrDale      29
# Blmngtn     23
# Veenker     23
# NPkVill     22
# Blueste     10
# Greens       8
# GrnHill      2
# Landmrk      1
# Name: Neighborhood_h, dtype: int64

# %%
housing.Neighborhood_r.value_counts()
# Out:
# N Ames     408
# CollgCr    236
# OldTown    207
# Edwards    162
# Gilbert    143
# Somerst    143
# Sawyer     139
# NW Ames    123
# NRidgHt    121
# SawyerW    112
# Mitchel    103
# BrkSide    102
# Crawfor     92
# IDOT&RR     69
# NoRidge     66
# Timber      52
# S&W ISU     41
# ClearCr     39
# MeadowV     34
# Br'Dale     29
# Blmngtn     23
# Veenker     23
# Stonebr     23
# NoPkVil     22
# HaydnLk     20
# Bluestm     10
# Greens       8
# Name: Neighborhood_r, dtype: int64

# %%
housing[housing.Neighborhood_r=='HaydnLk']
# Out:
#             PID  GrLivArea  SalePrice  MSSubClass MSZoning  LotFrontage  \
# 282   527212040       2576     361919          60       RL         82.0
# 292   527254020       2046     372500          20       RL         80.0
# 413   527214060       2698     535000          60       RL         82.0
# 473   527214030       1884     387000          20       RL         53.0
# 528   527258010       1856     394432          20       RL         88.0
# 601   527252090       1714     318000         120       RL         60.0
# 602   527258020       1530     260000          20       RL        124.0
# 620   527216080       2338     591587          20       RL         52.0
# 622   527252070       1419     392000          20       RL         60.0
# 634   527256040       2042     455000          20       RL         81.0
# 720   527210050       2473     356383          60       RL         63.0
# 749   527212050       2504     325000          60       RL         77.0
# 810   527216070       3279     538000          60       RL         47.0
# 1270  527210060       1922     377426          20       RL         86.0
# 1388  527252080       1710     334000         120       RL         60.0
# 1601  527208010       2500     355000          60       RL        101.0
# 1678  527252050       1612     319900         120       RL         61.0
# 1838  527212060       2541     349265          60       RL         98.0
# 2402  527256120       2000     470000          20       RL         90.0
# 2496  527256030       2234     441929          20       RL         85.0
#
#       LotArea Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 282     12438   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 292     11844   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 413     16052   Pave   NaN      IR1         Lvl    AllPub   CulDSac       Gtl
# 473     15401   Pave   NaN      IR1         HLS    AllPub   CulDSac       Gtl
# 528     11394   Pave   NaN      Reg         Lvl    AllPub    Corner       Gtl
# 601      8147   Pave   NaN      Reg         HLS    AllPub    Inside       Gtl
# 602     16158   Pave   NaN      IR1         Low    AllPub    Inside       Mod
# 620     51974   Pave   NaN      IR1         Lvl    AllPub   CulDSac       Gtl
# 622      8089   Pave   NaN      Reg         HLS    AllPub    Inside       Gtl
# 634     13870   Pave   NaN      IR1         HLS    AllPub    Inside       Gtl
# 720     12292   Pave   NaN      IR1         HLS    AllPub   CulDSac       Gtl
# 749     11198   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 810     53504   Pave   NaN      IR2         HLS    AllPub   CulDSac       Mod
# 1270    14157   Pave   NaN      IR1         HLS    AllPub    Corner       Gtl
# 1388     8118   Pave   NaN      Reg         HLS    AllPub    Inside       Gtl
# 1601    13543   Pave   NaN      IR1         HLS    AllPub    Corner       Gtl
# 1678     8035   Pave   NaN      IR1         HLS    AllPub    Inside       Gtl
# 1838    12328   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 2402    18261   Pave   NaN      IR1         HLS    AllPub    Inside       Gtl
# 2496    14082   Pave   NaN      IR1         HLS    AllPub    Inside       Gtl
#
#      Neighborhood_h Condition1 Condition2 BldgType HouseStyle  OverallQual  \
# 282         StoneBr       Norm       Norm     1Fam     2Story            8
# 292         StoneBr       Norm       Norm     1Fam     1Story            8
# 413         StoneBr       Norm       Norm     1Fam     2Story           10
# 473         StoneBr       Norm       Norm     1Fam     1Story            9
# 528         StoneBr       Norm       Norm     1Fam     1Story            9
# 601         StoneBr       Norm       Norm   TwnhsE     1Story            9
# 602         StoneBr       Norm       Norm     1Fam     1Story            7
# 620         StoneBr       PosN       Norm     1Fam     1Story            9
# 622         StoneBr       Norm       Norm     1Fam     1Story            8
# 634         StoneBr       PosA       PosA     1Fam     1Story           10
# 720         StoneBr       Norm       Norm     1Fam     2Story            9
# 749         StoneBr       Norm       Norm     1Fam     2Story            9
# 810         StoneBr       Norm       Norm     1Fam     2Story            8
# 1270        StoneBr       Norm       Norm     1Fam     1Story            9
# 1388        StoneBr       PosN       PosN   TwnhsE     1Story            9
# 1601        StoneBr       Norm       Norm     1Fam     2Story            8
# 1678        StoneBr       Norm       Norm   TwnhsE     1Story            9
# 1838        StoneBr       Norm       Norm     1Fam     2Story            8
# 2402        StoneBr       Norm       Norm     1Fam     1Story            9
# 2496        StoneBr       Norm       Norm     1Fam     1Story            8
#
#       OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st  \
# 282             5       2006          2006       Hip  CompShg     VinylSd
# 292             5       2008          2008       Hip  CompShg     VinylSd
# 413             5       2006          2006       Hip  CompShg     VinylSd
# 473             5       2004          2004       Hip  CompShg     VinylSd
# 528             2       2010          2010       Hip  CompShg     VinylSd
# 601             5       2005          2005       Hip  CompShg     MetalSd
# 602             5       2005          2005       Hip  CompShg     VinylSd
# 620             5       2006          2007       Hip  CompShg     VinylSd
# 622             6       2007          2007     Gable  CompShg     MetalSd
# 634             5       2006          2007       Hip  CompShg     CemntBd
# 720             5       2006          2006       Hip  CompShg     VinylSd
# 749             5       2005          2007       Hip  CompShg     VinylSd
# 810             5       2003          2003       Hip  CompShg     CemntBd
# 1270            5       2005          2006       Hip  CompShg     VinylSd
# 1388            5       2007          2007       Hip  CompShg     MetalSd
# 1601            5       2005          2005     Gable  CompShg     VinylSd
# 1678            5       2006          2006     Gable  CompShg     MetalSd
# 1838            5       2005          2005       Hip  CompShg     VinylSd
# 2402            5       2005          2005       Hip  CompShg     VinylSd
# 2496            5       2006          2006       Hip  CompShg     VinylSd
#
#      Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond Foundation  \
# 282      VinylSd    BrkFace       466.0        Ex        TA      PConc
# 292      VinylSd      Stone       464.0        Gd        TA      PConc
# 413      VinylSd      Stone       734.0        Ex        TA      PConc
# 473      VinylSd    BrkFace       296.0        Ex        TA      PConc
# 528      VinylSd      Stone       350.0        Gd        TA      PConc
# 601      MetalSd    BrkFace       230.0        Gd        TA      PConc
# 602      VinylSd      Stone        16.0        Gd        TA      PConc
# 620      VinylSd    BrkFace       710.0        Ex        TA      PConc
# 622      MetalSd    BrkFace         0.0        Gd        TA      PConc
# 634      CmentBd    BrkFace       250.0        Ex        TA      PConc
# 720      VinylSd    BrkFace       184.0        Gd        TA      PConc
# 749      VinylSd    BrkFace       245.0        Gd        TA      PConc
# 810      Wd Shng    BrkFace       603.0        Ex        TA      PConc
# 1270     VinylSd      Stone       200.0        Gd        TA      PConc
# 1388     MetalSd    BrkFace       178.0        Ex        TA      PConc
# 1601     VinylSd      Stone       130.0        Gd        TA      PConc
# 1678     MetalSd    BrkFace       165.0        Gd        TA      PConc
# 1838     VinylSd      Stone       146.0        Gd        TA      PConc
# 2402     VinylSd    BrkFace       420.0        Ex        TA      PConc
# 2496     VinylSd    BrkFace       945.0        Gd        TA      PConc
#
#      BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  \
# 282        Ex       Gd           No          Unf         0.0          Unf
# 292        Ex       TA           Mn          Unf         0.0          Unf
# 413        Ex       TA           No          GLQ      1206.0          Unf
# 473        Ex       TA           Gd          GLQ      1337.0          Unf
# 528        Ex       TA           Av          GLQ      1445.0          Unf
# 601        Ex       TA           Gd          GLQ      1191.0          Unf
# 602        Ex       TA           Av          ALQ      1274.0          Unf
# 620        Ex       TA           Av          GLQ      1101.0          Unf
# 622        Gd       TA           Av          GLQ       945.0          Unf
# 634        Ex       TA           Gd          GLQ      1152.0          Unf
# 720        Ex       Gd           Gd          GLQ       205.0          Unf
# 749        Gd       Gd           No          Unf         0.0          Unf
# 810        Gd       TA           Gd          ALQ      1416.0          Unf
# 1270       Ex       TA           Gd          GLQ      1249.0          Unf
# 1388       Ex       TA           Gd          GLQ      1034.0          Unf
# 1601       Ex       TA           Gd          GLQ        16.0          Unf
# 1678       Ex       TA           Gd          GLQ       797.0          Unf
# 1838       Ex       TA           Mn          GLQ       986.0          Unf
# 2402       Ex       TA           Gd          GLQ      1416.0          Unf
# 2496       Ex       Gd           Gd          GLQ      1558.0          Unf
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir  \
# 282          0.0     1234.0       1234.0    GasA        Ex          Y
# 292          0.0     2046.0       2046.0    GasA        Ex          Y
# 413          0.0      644.0       1850.0    GasA        Ex          Y
# 473          0.0      547.0       1884.0    GasA        Ex          Y
# 528          0.0      411.0       1856.0    GasA        Ex          Y
# 601          0.0      523.0       1714.0    GasA        Ex          Y
# 602          0.0      256.0       1530.0    GasA        Ex          Y
# 620          0.0     1559.0       2660.0    GasA        Ex          Y
# 622          0.0      474.0       1419.0    GasA        Ex          Y
# 634          0.0      590.0       1742.0    GasA        Ex          Y
# 720          0.0      889.0       1094.0    GasA        Ex          Y
# 749          0.0     1122.0       1122.0    GasA        Ex          Y
# 810          0.0      234.0       1650.0    GasA        Ex          Y
# 1270         0.0      673.0       1922.0    GasA        Ex          Y
# 1388         0.0      676.0       1710.0    GasA        Ex          Y
# 1601         0.0     1152.0       1168.0    GasA        Ex          Y
# 1678         0.0      815.0       1612.0    GasA        Ex          Y
# 1838         0.0      163.0       1149.0    GasA        Ex          Y
# 2402         0.0      494.0       1910.0    GasA        Ex          Y
# 2496         0.0      662.0       2220.0    GasA        Ex          Y
#
#      Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  BsmtFullBath  BsmtHalfBath  \
# 282       SBrkr      1264      1312             0           0.0           0.0
# 292       SBrkr      2046         0             0           0.0           0.0
# 413       SBrkr      1850       848             0           1.0           0.0
# 473       SBrkr      1884         0             0           1.0           0.0
# 528       SBrkr      1856         0             0           1.0           0.0
# 601       SBrkr      1714         0             0           1.0           0.0
# 602       SBrkr      1530         0             0           1.0           0.0
# 620       SBrkr      2338         0             0           1.0           0.0
# 622       SBrkr      1419         0             0           1.0           0.0
# 634       SBrkr      2042         0             0           1.0           0.0
# 720       SBrkr      1102      1371             0           0.0           0.0
# 749       SBrkr      1134      1370             0           0.0           0.0
# 810       SBrkr      1690      1589             0           1.0           0.0
# 1270      SBrkr      1922         0             0           1.0           0.0
# 1388      SBrkr      1710         0             0           1.0           0.0
# 1601      SBrkr      1168      1332             0           0.0           0.0
# 1678      SBrkr      1612         0             0           1.0           0.0
# 1838      SBrkr      1164      1377             0           1.0           0.0
# 2402      SBrkr      2000         0             0           1.0           0.0
# 2496      SBrkr      2234         0             0           1.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 282          2         1             4             1          Ex
# 292          2         1             3             1          Gd
# 413          2         1             4             1          Ex
# 473          2         0             2             1          Ex
# 528          1         1             1             1          Ex
# 601          2         0             2             1          Gd
# 602          2         0             3             1          Gd
# 620          2         1             4             1          Gd
# 622          2         0             2             1          Gd
# 634          2         0             3             1          Ex
# 720          2         1             4             1          Gd
# 749          2         1             4             1          Ex
# 810          3         1             4             1          Ex
# 1270         2         0             3             1          Gd
# 1388         2         0             2             1          Ex
# 1601         3         1             5             1          Ex
# 1678         2         0             2             1          Ex
# 1838         3         1             4             1          Ex
# 2402         2         1             3             1          Ex
# 2496         1         1             1             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 282             10        Typ           1          Gd    BuiltIn       2006.0
# 292              7        Typ           1          Gd     Attchd       2008.0
# 413             11        Typ           1          Gd     Attchd       2006.0
# 473              7        Typ           1          Gd     Attchd       2004.0
# 528              8        Typ           1          Ex     Attchd       2010.0
# 601              7        Typ           1          Gd     Attchd       2005.0
# 602              7        Typ           1          Gd     Attchd       2005.0
# 620              8        Typ           2          Gd     Attchd       2005.0
# 622              7        Typ           1          Gd     Attchd       2007.0
# 634              8        Typ           1          Gd     Attchd       2007.0
# 720             11        Typ           1          Gd    BuiltIn       2006.0
# 749             11        Typ           1          Gd    BuiltIn       2005.0
# 810             12        Mod           1          Gd    BuiltIn       2003.0
# 1270             8        Typ           1          Gd     Attchd       2005.0
# 1388             6        Typ           1          Gd     Attchd       2007.0
# 1601             9        Typ           1          Gd    BuiltIn       2005.0
# 1678             6        Typ           1          Gd     Attchd       2006.0
# 1838            10        Typ           1          Gd    BuiltIn       2005.0
# 2402             8        Typ           2          Gd     Attchd       2005.0
# 2496             7        Typ           1          Gd     Attchd       2006.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 282           Fin         3.0       666.0         TA         TA          Y
# 292           Fin         3.0       834.0         TA         TA          Y
# 413           RFn         3.0       736.0         TA         TA          Y
# 473           Fin         3.0       670.0         TA         TA          Y
# 528           Fin         3.0       834.0         TA         TA          Y
# 601           Fin         2.0       517.0         TA         TA          Y
# 602           Fin         2.0       430.0         TA         TA          Y
# 620           Fin         3.0      1110.0         Gd         TA          Y
# 622           RFn         2.0       567.0         TA         TA          Y
# 634           Fin         3.0       724.0         TA         TA          Y
# 720           Fin         3.0       675.0         TA         TA          Y
# 749           Fin         3.0       656.0         TA         TA          Y
# 810           Fin         3.0       841.0         TA         TA          Y
# 1270          Fin         3.0       676.0         TA         TA          Y
# 1388          RFn         2.0       557.0         TA         TA          Y
# 1601          Fin         3.0       683.0         TA         TA          Y
# 1678          Fin         2.0       556.0         TA         TA          Y
# 1838          Fin         3.0       729.0         TA         TA          Y
# 2402          Unf         3.0       722.0         TA         TA          Y
# 2496          RFn         2.0       724.0         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 282          324          100              0          0            0
# 292          322           82              0          0            0
# 413          250            0              0          0            0
# 473          214           76              0          0            0
# 528          113            0              0          0            0
# 601          156           55              0          0            0
# 602          168           36              0          0            0
# 620            0          135              0          0          322
# 622          140            0              0          0            0
# 634          240           52              0          0          174
# 720          246           39              0          0            0
# 749          144           39              0          0            0
# 810          503           36              0          0          210
# 1270         178           51              0          0            0
# 1388         156           48              0          0            0
# 1601         192           32              0          0            0
# 1678           0          164              0          0            0
# 1838         120           32              0          0            0
# 2402         351          102              0          0          123
# 2496         390           80              0          0            0
#
#       PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 282          0    NaN   NaN         NaN        0       7    2006      New
# 292          0    NaN   NaN         NaN        0       7    2009      New
# 413          0    NaN   NaN         NaN        0       7    2006      New
# 473          0    NaN   NaN         NaN        0       9    2008      WD
# 528          0    NaN   NaN         NaN        0       6    2010      New
# 601          0    NaN   NaN         NaN        0       8    2006      WD
# 602          0    NaN   NaN         NaN        0       6    2009      WD
# 620          0    NaN   NaN         NaN        0       6    2007      New
# 622          0    NaN   NaN         NaN        0      10    2007      New
# 634          0    NaN   NaN         NaN        0      10    2007      New
# 720          0    NaN   NaN         NaN        0       7    2006      New
# 749          0    NaN   NaN         NaN        0       6    2008      WD
# 810          0    NaN   NaN         NaN        0       6    2010      WD
# 1270         0    NaN   NaN         NaN        0       7    2007      WD
# 1388         0    NaN   NaN         NaN        0       7    2008      WD
# 1601         0    NaN   NaN         NaN        0       7    2008      WD
# 1678         0    NaN   NaN         NaN        0       3    2007      WD
# 1838         0    NaN   NaN         NaN        0       7    2007      WD
# 2402         0    NaN   NaN         NaN        0       9    2006      WD
# 2496         0    NaN   NaN         NaN        0       1    2007      WD
#
#      SaleCondition  LogSalePrice  LogGrLivArea  LogLotArea Neighborhood_r
# 282        Partial     12.799176      7.853993    9.428512        HaydnLk
# 292        Partial     12.827992      7.623642    9.379577        HaydnLk
# 413        Partial     13.190022      7.900266    9.683589        HaydnLk
# 473         Normal     12.866180      7.541152    9.642188        HaydnLk
# 528        Partial     12.885202      7.526179    9.340842        HaydnLk
# 601         Normal     12.669807      7.446585    9.005405        HaydnLk
# 602         Normal     12.468437      7.333023    9.690171        HaydnLk
# 620        Partial     13.290564      7.757051   10.858499        HaydnLk
# 622        Partial     12.879017      7.257708    8.998260        HaydnLk
# 634        Partial     13.028053      7.621685    9.537484        HaydnLk
# 720        Partial     12.783761      7.813187    9.416704        HaydnLk
# 749         Normal     12.691580      7.825645    9.323490        HaydnLk
# 810         Normal     13.195614      8.095294   10.887512        HaydnLk
# 1270        Normal     12.841130      7.561122    9.557964        HaydnLk
# 1388        Normal     12.718896      7.444249    9.001839        HaydnLk
# 1601        Normal     12.779873      7.824046    9.513625        HaydnLk
# 1678        Normal     12.675764      7.385231    8.991562        HaydnLk
# 1838        Normal     12.763586      7.840313    9.419628        HaydnLk
# 2402        Normal     13.060488      7.600902    9.812523        HaydnLk
# 2496        Normal     12.998905      7.711549    9.552653        HaydnLk

# %%
housing[housing.Neighborhood_h=='Landmrk']
# Out:
#             PID  GrLivArea  SalePrice  MSSubClass MSZoning  LotFrontage  \
# 1220  907230240       1320     137000         160       RH          NaN
#
#       LotArea Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 1220     3612   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood_h Condition1 Condition2 BldgType HouseStyle  OverallQual  \
# 1220        Landmrk       Norm       Norm    Twnhs     2Story            6
#
#       OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st  \
# 1220            5       1993          1994     Gable  CompShg     VinylSd
#
#      Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond Foundation  \
# 1220     VinylSd       None         0.0        TA        TA      PConc
#
#      BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  \
# 1220       Gd       TA           No          GLQ       338.0          Unf
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir  \
# 1220         0.0      292.0        630.0    GasA        Ex          Y
#
#      Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  BsmtFullBath  BsmtHalfBath  \
# 1220      SBrkr       630       690             0           0.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 1220         2         1             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 1220             5        Typ           0         NaN     Detchd       1993.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 1220          Unf         2.0       484.0         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 1220           0           48              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 1220         0    NaN  MnPrv         NaN        0       6    2006      WD
#
#      SaleCondition  LogSalePrice  LogGrLivArea  LogLotArea Neighborhood_r
# 1220        Normal     11.827736      7.185387    8.192017            NaN

# %% [markdown]
# **Conclusion:** Keep oringinal neighborhoods and drop neighborhoods that are too small

# %%
housing.rename(columns = {'Neighborhood_h':'Neighborhood'}, inplace = True)

# %% [markdown]
# ########################################################################################
# ########################################################################################
# # Isabel - keep everything below here
# ########################################################################################
# ########################################################################################

# %% [markdown]
# # Stephen's Basic EDA

# %% [markdown]
# Checking features for bad or sparse classes that we want to remove for linear model.

# %%
plt.figure(figsize=(6,6))
housing['Neighborhood'].value_counts().plot(kind='bar')
plt.title('Nieghborhood Distribution')
# Out:
# Text(0.5, 1.0, 'Nieghborhood Distribution')

# %%
plt.figure(figsize=(3,3))
housing['BldgType'].value_counts().plot(kind='bar')
plt.title('Building Type Distribution')
# Out:
# Text(0.5, 1.0, 'Building Type Distribution')

# %%
# plt.figure()
housing.MSZoning.value_counts().plot(kind='bar', figsize=(5,5))
plt.title('Distribution of Zoning')
# Out:
# Text(0.5, 1.0, 'Distribution of Zoning')

# %%
# plt.figure(figsize=(4,4))
housing.Functional.value_counts().plot(kind='bar', figsize=(5,5))
plt.title('Distribution of Functional Features')
# Out:
# Text(0.5, 1.0, 'Distribution of Functional Features')

# %%
plt.figure(figsize=(4,4))
housing.SaleType.value_counts().plot(kind='bar')
plt.title('Distribution of Sale Types')
# Out:
# Text(0.5, 1.0, 'Distribution of Sale Types')

# %%
plt.figure(figsize=(4,4))
housing.SaleCondition.value_counts().plot(kind='bar')
plt.title('Distribution of Sale Condition')
# Out:
# Text(0.5, 1.0, 'Distribution of Sale Condition')

# %%
plt.figure(figsize=(3,3))
housing['BedroomAbvGr'].value_counts().plot(kind='bar')
plt.title('Bedroom Count Distribution')
# Out:
# Text(0.5, 1.0, 'Bedroom Count Distribution')

# %% [markdown]
# # Analyze Montly Sale Prices

# %%
plt.figure(figsize=(5,5))
housing.groupby('MoSold').agg({'SalePrice':'mean'})['SalePrice'].plot()
plt.title('Monthly Sale Price')
# Out:
# Text(0.5, 1.0, 'Monthly Sale Price')

# %%
mo_sale = housing.groupby('MoSold').agg({'SalePrice':'mean'}).sort_values('SalePrice', ascending=False).reset_index()
mo_sale.index.names = ['DescOrder']
mo_sale
# Out:
#            MoSold      SalePrice
# DescOrder
# 0               1  189749.282828
# 1               9  183824.374046
# 2               8  183253.896373
# 3               6  181402.390830
# 4              11  181221.560345
# 5               7  180802.000000
# 6              12  179577.244186
# 7               2  178340.815126
# 8               3  174941.899522
# 9              10  174905.741497
# 10              5  172817.118457
# 11              4  167049.781746

# %%
fig, ax = plt.subplots(figsize=(6,6))
scatter = ax.scatter(mo_sale.index, mo_sale['SalePrice'], c=mo_sale['MoSold'])
legend1 = ax.legend(*scatter.legend_elements(),
                    loc="upper left", title="True Month")
ax.add_artist(legend1)
plt.title('Lowest to Highest Avg Monthly Sale Price')
plt.xlabel('Order')
# Out:
# Text(0.5, 0, 'Order')

# %% [markdown]
# **Conclusion:** We can create a re-ordered ordinal column for month and predict when the next best month to buy a house is. In addition, mortgage rates by month are not helpful, but mortgage rates are correlated with price on an annual basis. Unfortunately, the trend is in the opposite direction than we would expect, so it may not be useful.

# %% [markdown]
# # Analysis of Year Built

# %%
housing['BeenRemod'] = np.where(housing.YearRemodAdd != housing.YearBuilt, 1, 0)

# %%
housing[['YearBuilt','YearRemodAdd','BeenRemod']].sample(5)
# Out:
#       YearBuilt  YearRemodAdd  BeenRemod
# 1697       1958          1958          0
# 1990       1915          1950          1
# 1987       1979          1979          0
# 909        1958          1958          0
# 484        1977          1977          0

# %%
housing_year = housing[housing['BeenRemod']==0].groupby('YearBuilt').agg({'SalePrice':['count', 'mean', 'std', 'max', 'min']})
housing_year.head()
# Out:
#           SalePrice
#               count           mean           std     max    min
# YearBuilt
# 1950             20  114707.500000  19762.912335  152000  81400
# 1951             12  126116.666667  22031.375698  155000  81500
# 1952             10  121840.000000  20835.610542  166000  82000
# 1953             18  142650.000000  35346.956771  225000  93000
# 1954             24  132087.125000  27318.649230  224000  93000

# %%
housing_year[('SalePrice','count')].plot(kind='bar', figsize=(16,4))

# %%
housing_year[('SalePrice','mean')].plot(kind='bar', figsize=(16,4))

# %% [markdown]
# **Conclusion:** Slight linear trend in price over time

# %% [markdown]
# # Compare Annual Sale Price with Mortgage Rates

# %%
FRM = pd.read_csv('data/mortgage_rates.csv')
FRM = FRM.merge(housing.groupby(['YrSold','MoSold']).agg({'SalePrice':'mean'}), left_on=['Year', 'Month'], right_on=['YrSold','MoSold'])

# %%
fig, ax = plt.subplots(figsize=(6,6))
scatter = plt.scatter(FRM['FRM'], FRM['SalePrice'], c=FRM['Year'])
legend1 = ax.legend(*scatter.legend_elements(),
                    loc="upper left", title="Year")
ax.add_artist(legend1)
plt.title('Monthly Sale Price Based on Mortgage Rates')
plt.xlabel('30 Year Fixed Interest Mortgage Rate')
plt.ylabel('Monthly Average Sale Price')
# Out:
# Text(0, 0.5, 'Monthly Average Sale Price')

# %%
FRM2 = FRM.groupby('Year').agg({'SalePrice':'mean', 'FRM':'mean'})

fig, ax = plt.subplots(figsize = (6,6))
scatter = plt.scatter(FRM2['FRM'], FRM2['SalePrice'], c=list(FRM2.index))
legend1 = ax.legend(*scatter.legend_elements(),
                    loc="lower right", title="Year")
ax.add_artist(legend1)
plt.title('Annual Sale Price Based on Mortgage Rates')
plt.xlabel('30 Year Fixed Interest Mortgage Rate')
plt.ylabel('Annual Average Sale Price')
# Out:
# Text(0, 0.5, 'Annual Average Sale Price')

# %% [markdown]
# **Conclusion:** Opposite trend between mortgage rates and sale price - consider dropping the variable

# %% [markdown]
# # Binary Features (HasBLANK)

# %% [markdown]
# Exploring the binary categories to determine if they are significant

# %%
housing['BeenRemod'] = np.where(housing.YearBuilt != housing.YearRemodAdd, 1, 0)
housing['HasFinBsmt'] = np.where(housing.BsmtFinSF1 > 0, 1, 0)
housing['HasFinGarage'] = np.where(housing.GarageFinish == "Fin", 1, 0)
housing['HasPool'] = np.where(housing.PoolArea > 0, 1, 0)
housing['HasFireplace'] = np.where(housing.Fireplaces > 0, 1, 0)
housing['PorchTotSF'] = housing.OpenPorchSF + housing.EnclosedPorch + housing['3SsnPorch'] + housing.ScreenPorch
housing['HasPorch'] = np.where(housing.PorchTotSF > 0, 1, 0)
housing['HasDeck'] = np.where(housing.WoodDeckSF > 0, 1, 0)

# %%
cols = ['BeenRemod', 'HasFinBsmt', 'HasFinGarage', 'HasPool', 'HasFireplace', 'HasPorch', 'HasDeck']
for col_ in cols:
    plt.figure(figsize=(3,3))
    housing[col_].value_counts().plot(kind='bar')
    plt.title(col_)

# %%
from scipy import stats
for col_ in cols:
    print('Does ' + col_ + ' have a significant effect?\n')
    print(housing.groupby(col_).agg({'SalePrice':['mean','std']})/1000)
    a = housing[housing[col_]==0].SalePrice
    b = housing[housing[col_]==1].SalePrice
    t, p = stats.ttest_ind(a, b)
    print('\nUsing a paired t-test, the t-score is %f, and the p value is %f \n' % (t,p))
    diff_ = (np.mean(b) - np.mean(a))/1000
    print('On average, houses with ' + col_ + ' are worth %.0f thousand more dollars.\n' % diff_)
# Out:
# Does BeenRemod have a significant effect?
#
#             SalePrice
#                  mean        std
# BeenRemod
# 0          181.818730  70.327479
# 1          173.901153  77.778121
#
# Using a paired t-test, the t-score is 2.710148, and the p value is 0.006770
#
# On average, houses with BeenRemod are worth -8 thousand more dollars.
#
# Does HasFinBsmt have a significant effect?
#
#              SalePrice
#                   mean        std
# HasFinBsmt
# 0           158.528381  62.802092
# 1           186.575317  76.728772
#
# Using a paired t-test, the t-score is -8.947201, and the p value is 0.000000
#
# On average, houses with HasFinBsmt are worth 28 thousand more dollars.
#
# Does HasFinGarage have a significant effect?
#
#                SalePrice
#                     mean        std
# HasFinGarage
# 0             161.361142  60.117890
# 1             231.081579  87.324976
#
# Using a paired t-test, the t-score is -22.346573, and the p value is 0.000000
#
# On average, houses with HasFinGarage are worth 70 thousand more dollars.
#
# Does HasPool have a significant effect?
#
#           SalePrice
#                mean         std
# HasPool
# 0        177.894666   73.476336
# 1        255.944444  146.843974
#
# Using a paired t-test, the t-score is -3.166429, and the p value is 0.001561
#
# On average, houses with HasPool are worth 78 thousand more dollars.
#
# Does HasFireplace have a significant effect?
#
#                SalePrice
#                     mean        std
# HasFireplace
# 0             141.070412  41.174104
# 1             212.488397  80.682514
#
# Using a paired t-test, the t-score is -27.935662, and the p value is 0.000000
#
# On average, houses with HasFireplace are worth 71 thousand more dollars.
#
# Does HasPorch have a significant effect?
#
#            SalePrice
#                 mean        std
# HasPorch
# 0         145.550599  50.311325
# 1         192.495975  78.022511
#
# Using a paired t-test, the t-score is -15.500828, and the p value is 0.000000
#
# On average, houses with HasPorch are worth 47 thousand more dollars.
#
# Does HasDeck have a significant effect?
#
#           SalePrice
#                mean        std
# HasDeck
# 0        156.209877  59.480769
# 1        201.608369  80.425725
#
# Using a paired t-test, the t-score is -16.344920, and the p value is 0.000000
#
# On average, houses with HasDeck are worth 45 thousand more dollars.

# %% [markdown]
# **Conclusion:** All of these features are significantly related to the sale price. Are they correlated?

# %%
housing[cols].corr()
# Out:
#               BeenRemod  HasFinBsmt  HasFinGarage   HasPool  HasFireplace  \
# BeenRemod      1.000000   -0.133599     -0.056336 -0.041608      0.021768
# HasFinBsmt    -0.133599    1.000000      0.071139 -0.004342      0.094249
# HasFinGarage  -0.056336    0.071139      1.000000  0.028178      0.285546
# HasPool       -0.041608   -0.004342      0.028178  1.000000      0.043819
# HasFireplace   0.021768    0.094249      0.285546  0.043819      1.000000
# HasPorch       0.110058   -0.059555      0.132710 -0.003619      0.227732
# HasDeck       -0.041568    0.091547      0.227598  0.034875      0.217725
#
#               HasPorch   HasDeck
# BeenRemod     0.110058 -0.041568
# HasFinBsmt   -0.059555  0.091547
# HasFinGarage  0.132710  0.227598
# HasPool      -0.003619  0.034875
# HasFireplace  0.227732  0.217725
# HasPorch      1.000000  0.040010
# HasDeck       0.040010  1.000000

# %% [markdown]
# **Conclusion:** weak correlation b/t HasFireplace and HasDeck and b/t HasFireplace and HasDeck

# %%
from sklearn.linear_model import Lasso
from sklearn import model_selection

housing['LogSalePrice'] = np.log(housing.SalePrice)
housing['LogGrLivArea'] = np.log(housing.GrLivArea)

x1 = housing[cols]
x1['LogGrLivArea'] = housing['LogGrLivArea']
x1['LogLotArea'] = housing['LogLotArea']
y = housing['LogSalePrice']
y = np.log(y)

param_grid={'alpha': np.logspace(-5, -3, 100)}
grid_search = model_selection.GridSearchCV(estimator = Lasso(), param_grid = param_grid, cv=3)
grid_search.fit(x1, y)

print(grid_search.best_estimator_)
print(grid_search.best_params_)
print(grid_search.best_score_)

alpha_cv = grid_search.best_estimator_.get_params()['alpha']

lasso = Lasso(alpha = alpha_cv).fit(x1, y)
coef = pd.Series(lasso.coef_, index = x1.columns)
imp_coef = pd.concat([coef.sort_values()])
imp_coef.plot(kind = "bar", figsize = (12, 8))
plt.title("Coefficients in the Lasso Model")
# Out:
# D:\Software\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# D:\Software\anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# Lasso(alpha=3.678379771828634e-05, copy_X=True, fit_intercept=True,
#       max_iter=1000, normalize=False, positive=False, precompute=False,
#       random_state=None, selection='cyclic', tol=0.0001, warm_start=False)
# {'alpha': 3.678379771828634e-05}
# 0.6876701965310056
# Text(0.5, 1.0, 'Coefficients in the Lasso Model')

# %% [markdown]
# # Non-Linear Combinations of HasBLANK

# %%
x1 = housing[cols]
i = 1
n = 8
for col1 in cols:    # generate interaction columns
    for col2 in cols[i:]:
        new_col = col1 + col2
        x1[new_col] = x1[col1] * x1[col2]
        # drop if no new information
        new_sum = np.sum(x1[new_col])
        if (new_sum == np.sum(x1[col1])) or (new_sum == np.sum(x1[col2])):
            x1 = x1.drop(new_col, axis=1)
            print("Dropping column: '%s' for providing no new information" % new_col)
        elif (new_sum < 9):
            x1 = x1.drop(new_col, axis=1)
            print("Dropping column: '%s' with less than %i observations" % (new_col, n))
    i = i+1
        
x1.hist(figsize=(16,16))
# Out:
# D:\Software\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# Dropping column: 'BeenRemodHasPool' with less than 8 observations
# Dropping column: 'HasFinBsmtHasPool' with less than 8 observations
# Dropping column: 'HasFinGarageHasPool' with less than 8 observations
# Dropping column: 'HasPoolHasFireplace' with less than 8 observations
# Dropping column: 'HasPoolHasPorch' with less than 8 observations
# Dropping column: 'HasPoolHasDeck' with less than 8 observations
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001654566FC48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000165457AB208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016545375388>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016544DBFDC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016544C5F648>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000165456F4608>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000165456D9588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016545798308>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016545789188>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000165456660C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001654565DC08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016547B1DD08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016548C43D88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016548C7CE88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016549104F88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000016549142048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001654917A0C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000165491B2148>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000165491EB248>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016549224388>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001654925E488>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016549297588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000165492CE648>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016549497808>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000165494D09C8>]],
#       dtype=object)

# %%
x1['LogGrLivArea'] = housing['LogGrLivArea']
x1['LogLotArea'] = housing['LogLotArea']
y = housing['LogSalePrice']
y = np.log(y)

grid_search.fit(x1, y)

print(grid_search.best_estimator_)
print(grid_search.best_params_)
print(grid_search.best_score_)

alpha_cv = grid_search.best_estimator_.get_params()['alpha']

lasso = Lasso(alpha = alpha_cv).fit(x1, y)
coef = pd.Series(lasso.coef_, index = x1.columns)
imp_coef = pd.concat([coef.sort_values()])
imp_coef.plot(kind = "bar", figsize = (12, 8))
plt.title("Coefficients in the Lasso Model")
# Out:
# Lasso(alpha=2.782559402207126e-05, copy_X=True, fit_intercept=True,
#       max_iter=1000, normalize=False, positive=False, precompute=False,
#       random_state=None, selection='cyclic', tol=0.0001, warm_start=False)
# {'alpha': 2.782559402207126e-05}
# 0.6940663280178243
# Text(0.5, 1.0, 'Coefficients in the Lasso Model')

# %% [markdown]
# **Conclusion:** There are a couple feature interactions that could be useful, like Fireplace + Porch, Porch + Deck, and FinGarage + FinBasement. However, these are not good candidates for the model because they are difficult to integrate into the app.

# %% [markdown]
# # Feature Selection for Utility Varaibles

# %%
util_cols = ['Heating','HeatingQC','CentralAir','Electrical','Functional']
for col_ in util_cols:
    plt.figure(figsize=(3,3))
    housing[col_].value_counts().plot(kind='bar')
    plt.title(col_)

# %%
housing_utils = housing[util_cols]
housing_utils['LogGrLivArea'] = housing['LogGrLivArea']
housing_utils['LogLotArea'] = housing['LogLotArea']
housing_utils['LogSalePrice'] = housing['LogSalePrice']
housing_utils = housing_utils.dropna()
housing_utils_dummified = pd.get_dummies(housing_utils).drop(['Heating_GasA','HeatingQC_Ex','HeatingQC_Po','Electrical_SBrkr','Functional_Typ', 'CentralAir_Y'], axis=1)

x4 = housing_utils_dummified.drop('LogSalePrice', axis = 1)
y = housing_utils['LogSalePrice']

grid_search.fit(x4, y)
print(grid_search.best_estimator_)
print(grid_search.best_params_)
print(grid_search.best_score_)

alpha_cv = grid_search.best_estimator_.get_params()['alpha']
lasso = Lasso(alpha = alpha_cv).fit(x4, y)
coef = pd.Series(lasso.coef_, index = x4.columns)
imp_coef = pd.concat([coef.sort_values()])
imp_coef.plot(kind = "bar", figsize = (12, 8))
plt.title("Coefficients in the Lasso Model")
# Out:
# D:\Software\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# D:\Software\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# D:\Software\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# Lasso(alpha=2.4201282647943835e-05, copy_X=True, fit_intercept=True,
#       max_iter=1000, normalize=False, positive=False, precompute=False,
#       random_state=None, selection='cyclic', tol=0.0001, warm_start=False)
# {'alpha': 2.4201282647943835e-05}
# 0.6909836289479507
# Text(0.5, 1.0, 'Coefficients in the Lasso Model')

# %% [markdown]
# **Conclusion:** Some of the utility variables are good candidats to make binary, and it's worth deleting the functional varaible

# %% [markdown]
# # Feature Selection for Garage Variables

# %%
garage_cols = ['GarageType','GarageYrBlt','GarageFinish','GarageCars','GarageArea','GarageQual','GarageCond']
for col_ in garage_cols:
    plt.figure(figsize=(3,3))
    housing[col_].value_counts().plot(kind='bar')
    plt.title(col_)

# %%
housing_garages = housing[garage_cols]
housing_garages['LogGrLivArea'] = housing['LogGrLivArea']
housing_garages['LogSalePrice'] = housing['LogSalePrice']
housing_garages = housing_garages.dropna()
housing_garages_dummified = pd.get_dummies(housing_garages).drop(['GarageType_Attchd','GarageFinish_Unf','GarageQual_TA','GarageCond_TA'], axis=1)

x3 = housing_garages_dummified.drop('LogSalePrice', axis = 1)
y = housing_garages['LogSalePrice']

grid_search.fit(x3, y)
print(grid_search.best_estimator_)
print(grid_search.best_params_)
print(grid_search.best_score_)

alpha_cv = grid_search.best_estimator_.get_params()['alpha']
lasso = Lasso(alpha = alpha_cv).fit(x3, y)
coef = pd.Series(lasso.coef_, index = x3.columns)
imp_coef = pd.concat([coef.sort_values()])
imp_coef.plot(kind = "bar", figsize = (12, 8))
plt.title("Coefficients in the Lasso Model")
# Out:
# D:\Software\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# D:\Software\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# Lasso(alpha=0.0001291549665014884, copy_X=True, fit_intercept=True,
#       max_iter=1000, normalize=False, positive=False, precompute=False,
#       random_state=None, selection='cyclic', tol=0.0001, warm_start=False)
# {'alpha': 0.0001291549665014884}
# 0.7402175945828734
# Text(0.5, 1.0, 'Coefficients in the Lasso Model')

# %% [markdown]
# **Conclusions:** Lasso penalized regression eliminates several garage varaibles, including the garage area, garage year built, and most interestingly, the garage *quality*. The most important positive varaibles are the number of cars and whether the garage is finished or not (consider combining Fin + RFN). The most important negative variables are unattached garages (consider combining all unattached) and having a fair/poor garage condition (consider combining).

# %% [markdown]
# # Feature Selection for Overall Quality/Condition

# %%
over = housing[['OverallQual', 'OverallCond']]

# %%
over.OverallQual.hist()

# %%
over.OverallCond.hist()

# %%
over.OverallQual = over.OverallQual.astype(str)
over.OverallCond = over.OverallCond.astype(str)
over['LogSalePrice'] = np.log(housing.SalePrice)
over['LogGrLivArea'] = np.log(housing.GrLivArea)
over['LogLotArea'] = np.log(housing.LotArea)
over = over.dropna()
overall_dummified = pd.get_dummies(over).drop(['OverallQual_5', 'OverallCond_5'], axis=1)
# Out:
# D:\Software\anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# D:\Software\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# D:\Software\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# D:\Software\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
x2 = overall_dummified.drop(['LogSalePrice'], axis=1)
y = overall_dummified['LogSalePrice']

param_grid={'alpha': np.logspace(-5, -3, 100)}
grid_search = model_selection.GridSearchCV(estimator = Lasso(), param_grid = param_grid, cv=3)
grid_search.fit(x2, y)

print(grid_search.best_estimator_)
print(grid_search.best_params_)
print(grid_search.best_score_)

alpha_cv = grid_search.best_estimator_.get_params()['alpha']

lasso = Lasso(alpha = alpha_cv).fit(x2, y)
coef = pd.Series(lasso.coef_, index = x2.columns)
imp_coef = pd.concat([coef.sort_values()])
imp_coef.plot(kind = "bar", figsize = (12, 8))
plt.title("Coefficients in the Lasso Model")
# Out:
# Lasso(alpha=1e-05, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)
# {'alpha': 1e-05}
# 0.8163683780390985
# Text(0.5, 1.0, 'Coefficients in the Lasso Model')

# %% [markdown]
# **Conclusion:** Consider stratifying the Quality High/Avg/Low as (10-7)/(6-4)/(3-1) and Condition High/Avg/Low as (9-6)/(5)/(4-1)
